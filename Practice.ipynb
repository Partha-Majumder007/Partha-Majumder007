# %% [markdown]
# <a href="https://colab.research.google.com/github/Partha-Majumder007/Partha-Majumder007/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
You are given a small dictionary of customer information. Convert it into a pandas DataFrame and perform basic data cleaning and filtering.



data = {

    'CustomerID': [101, 102, 103, 104, 105, 106, 107],

    'Name': [' alice ', 'BOB', 'Charlie', None, 'Eve', '  frank', 'Grace'],

    'Age': ['25', 'thirty', '35', '40', None, '29', '27'],

    'City': ['New York', 'los angeles ', 'CHICAGO', 'New York', 'Chicago', None, 'new york'],

    'SignupDate': ['2022-01-01', '2022-02-15', None, '2022-03-01', 'invalid', '2022-03-15', '2022-03-20'],

}

Tasks:
Create the DataFrame


Load the dictionary into a pandas DataFrame.


Clean the Data


Strip whitespaces from Name and City.


Convert Name to title case and City to lowercase.


Convert Age to numeric, setting errors to NaN.


Convert SignupDate to datetime, coercing errors.


Handle Missing Data


Drop rows where Name or City is missing.


Fill missing Age with the median value.


Filter the Data

Show only customers from new york with Age < 30 and valid signup dates (non-NaT).


Display only CustomerID, Name, and Age columns.

# %%
from datetime import datetime
import pandas as pd
data = {'CustomerID': [101, 102, 103, 104, 105, 106, 107],
        'Name': [' alice ', 'BOB', 'Charlie', None, 'Eve', '  frank', 'Grace'],
        'Age': ['25', 'thirty', '35', '40', None, '29', '27'],
        'City': ['New York', 'los angeles ', 'CHICAGO', 'New York', 'Chicago', None, 'new york'],
        'SignupDate': ['2022-01-01', '2022-02-15', None, '2022-03-01', 'invalid', '2022-03-15', '2022-03-20']}
df=pd.DataFrame(data)
df["Name"]=df["Name"].str.strip()
df["City"]=df["City"].str.strip()
df["Name"]=df["Name"].str.title()
df["City"]=df["City"].str.lower()
df["Age"]=pd.to_numeric(df["Age"],errors="coerce")
df=df.dropna(subset=["Name","City"],how="any")
df["SignupDate"]=pd.to_datetime(df['SignupDate'],errors="coerce")
df['Age']=df['Age'].fillna(df["Age"].median())
df_2=df[(df["City"]=="new york") & (df["Age"]<30) & (df["SignupDate"].notna())]
df_2
df[["CustomerID","Name","Age"]]
# Out:
#    CustomerID     Name   Age
# 0         101    Alice  25.0
# 1         102      Bob  27.0
# 2         103  Charlie  35.0
# 4         105      Eve  27.0
# 6         107    Grace  27.0
